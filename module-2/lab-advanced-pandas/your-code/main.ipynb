# %% [markdown]
# # Before your start:
# - Read the README.md file
# - Comment as much as you can and use the resources (README.md file)
# - Happy learning!

# %%
# import numpy and pandas
import pandas as pd
import numpy as np

# %% [markdown]
# # Challenge 1 - Index Functions
#
# In this challenge, we will practice the advanced functions introduced in the lesson. However, before we start, we will load and evaluate our dataset.

# %%
# Run this code:

admissions = pd.read_csv('../Admission_Predict.csv')
#to remove trailing spaces at the end of the column names
admissions.columns = admissions.columns.str.rstrip()

# %% [markdown]
# Let's evaluate the dataset by looking at the `head` function.

# %%
# Your code here:
admissions.head()
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  \
# 0           1        337          118                  4  4.5  4.5  9.65
# 1           2        316          104                  3  3.0  3.5  8.00
# 2           3        322          110                  3  3.5  2.5  8.67
# 3           4        314          103                  2  2.0  3.0  8.21
# 4           5        330          115                  5  4.5  3.0  9.34
#
#    Research  Chance of Admit
# 0         1             0.92
# 1         1             0.72
# 2         1             0.80
# 3         0             0.65
# 4         1             0.90

# %% [markdown]
# Before beginning to work with this dataset and evaluating graduate admissions data, we will verify that there is no missing data in the dataset. Do this in the cell below.

# %%
# Your code here:
print(len(admissions))
print(admissions.notna().sum())
# Out:
# 385
# Serial No.           385
# GRE Score            385
# TOEFL Score          385
# University Rating    385
# SOP                  385
# LOR                  385
# CGPA                 385
# Research             385
# Chance of Admit      385
# dtype: int64

# %% [markdown]
# Interestingly, there is a column that uniquely identifies the applicants. This column is the serial number column. Instead of having our own index, we should make this column our index. Do this in the cell below. Keep the column in the dataframe in addition to making it an index.

# %%
# Your code here:
admissions.set_index('Serial No.', inplace = True)
admissions.head()
# Out:
#             GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  \
# Serial No.
# 1                 337          118                  4  4.5  4.5  9.65
# 2                 316          104                  3  3.0  3.5  8.00
# 3                 322          110                  3  3.5  2.5  8.67
# 4                 314          103                  2  2.0  3.0  8.21
# 5                 330          115                  5  4.5  3.0  9.34
#
#             Research  Chance of Admit
# Serial No.
# 1                  1             0.92
# 2                  1             0.72
# 3                  1             0.80
# 4                  0             0.65
# 5                  1             0.90

# %% [markdown]
# Turns out that `GRE Score` and `CGPA` also uniquely identify the data. Show this in the cell below.

# %%
# Your code here:
combination = zip(admissions['GRE Score'], admissions['CGPA'])
list(combination)
# Out:
# [(337, 9.65),
#  (316, 8.0),
#  (322, 8.67),
#  (314, 8.21),
#  (330, 9.34),
#  (321, 8.2),
#  (308, 7.9),
#  (302, 8.0),
#  (323, 8.6),
#  (327, 9.0),
#  (328, 9.1),
#  (307, 8.0),
#  (311, 8.2),
#  (314, 8.3),
#  (317, 8.7),
#  (319, 8.0),
#  (318, 8.8),
#  (303, 8.5),
#  (325, 8.4),
#  (328, 9.5),
#  (334, 9.7),
#  (336, 9.8),
#  (322, 8.8),
#  (298, 7.5),
#  (295, 7.2),
#  (310, 7.3),
#  (300, 8.1),
#  (327, 8.3),
#  (338, 9.4),
#  (340, 9.6),
#  (331, 9.8),
#  (320, 9.2),
#  (299, 8.4),
#  (300, 7.8),
#  (304, 7.5),
#  (307, 7.7),
#  (308, 8.0),
#  (316, 8.2),
#  (313, 8.5),
#  (332, 9.1),
#  (326, 9.4),
#  (322, 9.1),
#  (329, 9.3),
#  (339, 9.7),
#  (321, 8.85),
#  (327, 8.4),
#  (313, 8.3),
#  (312, 7.9),
#  (334, 8.0),
#  (324, 8.1),
#  (322, 8.0),
#  (320, 7.7),
#  (316, 7.4),
#  (298, 7.6),
#  (300, 6.8),
#  (311, 8.3),
#  (309, 8.1),
#  (307, 8.2),
#  (304, 8.2),
#  (315, 8.5),
#  (325, 8.7),
#  (325, 8.92),
#  (327, 9.02),
#  (316, 8.64),
#  (318, 9.22),
#  (328, 9.16),
#  (332, 9.64),
#  (336, 9.76),
#  (321, 9.45),
#  (314, 9.04),
#  (314, 8.9),
#  (329, 8.56),
#  (327, 8.72),
#  (301, 8.22),
#  (296, 7.54),
#  (294, 7.36),
#  (312, 8.02),
#  (340, 9.5),
#  (320, 9.22),
#  (322, 9.36),
#  (340, 9.45),
#  (319, 8.66),
#  (315, 8.42),
#  (317, 8.28),
#  (314, 8.14),
#  (318, 7.92),
#  (299, 7.66),
#  (298, 8.03),
#  (301, 7.88),
#  (303, 7.66),
#  (304, 7.84),
#  (306, 8.0),
#  (331, 8.96),
#  (332, 9.24),
#  (323, 8.88),
#  (322, 8.46),
#  (312, 8.12),
#  (314, 8.25),
#  (317, 8.47),
#  (326, 9.05),
#  (316, 8.78),
#  (329, 9.18),
#  (338, 9.46),
#  (331, 9.38),
#  (304, 8.64),
#  (305, 8.48),
#  (321, 8.68),
#  (301, 8.34),
#  (320, 8.56),
#  (311, 8.45),
#  (310, 9.04),
#  (299, 8.62),
#  (290, 7.46),
#  (296, 7.28),
#  (327, 8.84),
#  (335, 9.56),
#  (334, 9.48),
#  (310, 8.36),
#  (308, 8.22),
#  (301, 8.47),
#  (300, 8.66),
#  (323, 9.32),
#  (319, 8.71),
#  (326, 9.1),
#  (333, 9.35),
#  (339, 9.76),
#  (303, 8.65),
#  (323, 8.78),
#  (333, 9.28),
#  (314, 8.77),
#  (316, 8.16),
#  (326, 9.08),
#  (318, 9.12),
#  (329, 9.15),
#  (332, 9.36),
#  (331, 9.44),
#  (340, 9.92),
#  (325, 8.96),
#  (320, 8.64),
#  (315, 8.48),
#  (326, 9.11),
#  (339, 9.8),
#  (311, 8.26),
#  (334, 9.43),
#  (332, 9.28),
#  (321, 9.06),
#  (324, 8.75),
#  (326, 8.89),
#  (312, 8.69),
#  (315, 8.34),
#  (309, 8.26),
#  (306, 8.14),
#  (297, 7.9),
#  (315, 7.86),
#  (298, 7.46),
#  (318, 8.5),
#  (317, 8.56),
#  (329, 9.01),
#  (322, 8.97),
#  (302, 8.33),
#  (313, 8.27),
#  (293, 7.8),
#  (311, 7.98),
#  (312, 8.04),
#  (334, 9.07),
#  (322, 9.13),
#  (323, 9.23),
#  (321, 8.97),
#  (320, 8.87),
#  (329, 9.16),
#  (319, 9.04),
#  (309, 8.12),
#  (307, 8.27),
#  (300, 8.16),
#  (305, 8.42),
#  (299, 7.88),
#  (314, 8.8),
#  (327, 9.11),
#  (317, 8.68),
#  (335, 9.44),
#  (331, 9.36),
#  (324, 9.16),
#  (323, 8.98),
#  (322, 8.94),
#  (336, 9.53),
#  (316, 8.76),
#  (307, 8.52),
#  (306, 8.26),
#  (310, 8.33),
#  (313, 8.69),
#  (317, 8.54),
#  (315, 8.46),
#  (340, 9.91),
#  (334, 9.87),
#  (298, 8.54),
#  (295, 7.65),
#  (315, 7.89),
#  (310, 8.02),
#  (305, 8.16),
#  (301, 8.12),
#  (325, 9.06),
#  (328, 9.14),
#  (338, 9.66),
#  (333, 9.78),
#  (331, 9.42),
#  (330, 9.36),
#  (322, 9.26),
#  (321, 9.13),
#  (324, 8.97),
#  (312, 8.42),
#  (313, 8.75),
#  (316, 8.56),
#  (308, 8.45),
#  (305, 8.23),
#  (296, 8.03),
#  (306, 8.45),
#  (318, 8.67),
#  (324, 9.01),
#  (313, 8.65),
#  (319, 8.33),
#  (312, 8.27),
#  (304, 8.07),
#  (330, 9.31),
#  (326, 9.23),
#  (325, 9.17),
#  (329, 9.19),
#  (310, 8.37),
#  (299, 7.89),
#  (296, 7.68),
#  (317, 8.15),
#  (324, 8.76),
#  (325, 9.04),
#  (314, 8.56),
#  (328, 9.02),
#  (316, 8.73),
#  (311, 8.48),
#  (324, 8.87),
#  (321, 8.83),
#  (320, 8.57),
#  (316, 9.0),
#  (318, 8.54),
#  (335, 9.68),
#  (321, 9.12),
#  (307, 8.37),
#  (309, 8.56),
#  (324, 8.64),
#  (331, 9.34),
#  (327, 9.13),
#  (312, 8.09),
#  (308, 8.36),
#  (324, 8.79),
#  (325, 8.76),
#  (313, 8.68),
#  (312, 8.45),
#  (314, 8.17),
#  (327, 9.14),
#  (308, 8.34),
#  (306, 8.22),
#  (299, 7.86),
#  (294, 7.64),
#  (312, 8.01),
#  (315, 7.95),
#  (322, 8.96),
#  (329, 9.45),
#  (320, 8.62),
#  (308, 8.49),
#  (304, 8.73),
#  (311, 8.64),
#  (317, 9.11),
#  (312, 8.79),
#  (321, 8.9),
#  (340, 9.66),
#  (331, 9.26),
#  (336, 9.19),
#  (324, 9.08),
#  (314, 9.02),
#  (313, 9.0),
#  (307, 7.65),
#  (300, 7.87),
#  (302, 7.97),
#  (312, 8.18),
#  (316, 8.32),
#  (317, 8.57),
#  (310, 8.67),
#  (320, 9.11),
#  (330, 9.24),
#  (305, 8.65),
#  (309, 8.0),
#  (319, 8.76),
#  (322, 8.45),
#  (323, 8.55),
#  (313, 8.43),
#  (321, 8.8),
#  (323, 9.1),
#  (325, 9.0),
#  (312, 8.53),
#  (308, 8.6),
#  (320, 8.74),
#  (328, 9.18),
#  (311, 9.0),
#  (301, 8.04),
#  (308, 8.07),
#  (298, 7.86),
#  (300, 8.01),
#  (324, 8.8),
#  (327, 8.69),
#  (317, 8.5),
#  (323, 8.44),
#  (314, 8.27),
#  (305, 8.18),
#  (315, 8.33),
#  (326, 9.14),
#  (299, 8.02),
#  (295, 7.86),
#  (324, 8.77),
#  (297, 7.89),
#  (327, 8.66),
#  (311, 8.12),
#  (308, 8.21),
#  (319, 8.54),
#  (312, 8.65),
#  (319, 8.79),
#  (332, 9.47),
#  (323, 8.74),
#  (324, 8.66),
#  (312, 8.46),
#  (326, 8.76),
#  (308, 8.24),
#  (305, 8.13),
#  (295, 7.34),
#  (316, 7.43),
#  (304, 7.64),
#  (299, 7.34),
#  (302, 7.25),
#  (313, 8.04),
#  (318, 8.27),
#  (325, 8.67),
#  (303, 8.06),
#  (300, 8.17),
#  (297, 7.67),
#  (317, 8.12),
#  (327, 8.77),
#  (301, 7.89),
#  (314, 7.64),
#  (321, 8.44),
#  (322, 8.64),
#  (334, 9.54),
#  (338, 9.23),
#  (306, 8.36),
#  (313, 8.9),
#  (330, 9.17),
#  (320, 8.34),
#  (311, 7.46),
#  (298, 7.88),
#  (301, 8.03),
#  (310, 8.24),
#  (324, 9.22),
#  (336, 9.62),
#  (321, 8.54),
#  (315, 7.65),
#  (304, 7.66),
#  (297, 7.43),
#  (290, 7.56),
#  (303, 7.65),
#  (311, 8.43),
#  (322, 8.84),
#  (319, 8.67),
#  (324, 9.15),
#  (300, 8.26),
#  (340, 9.74),
#  (335, 9.82),
#  (302, 7.96),
#  (307, 8.1),
#  (296, 7.8),
#  (320, 8.44),
#  (314, 8.24),
#  (318, 8.65),
#  (326, 9.12),
#  (317, 8.76),
#  (329, 9.23),
#  (324, 9.04),
#  (325, 9.11),
#  (330, 9.45),
#  (312, 8.78),
#  (333, 9.66)]

# %% [markdown]
# Replace the index with an index comprised of two columns - `GRE Score` and `CGPA`. Remove the columns from the dataset as well. Make sure to use `inplace=True`.

# %% [markdown]
# Now change the index back to a sequence starting at zero using the `reset_index` function. Make sure to use `inplace=True`.

# %%
# Your code here:
admissions.set_index(['CGPA', 'GRE Score'], inplace = True, drop = True)
admissions.head()
# Out:
#                 TOEFL Score  University Rating  SOP  LOR  Research  \
# CGPA GRE Score
# 9.65 337                118                  4  4.5  4.5         1
# 8.00 316                104                  3  3.0  3.5         1
# 8.67 322                110                  3  3.5  2.5         1
# 8.21 314                103                  2  2.0  3.0         0
# 9.34 330                115                  5  4.5  3.0         1
#
#                 Chance of Admit
# CGPA GRE Score
# 9.65 337                   0.92
# 8.00 316                   0.72
# 8.67 322                   0.80
# 8.21 314                   0.65
# 9.34 330                   0.90

# %%
admissions.reset_index(inplace = True)
admissions.head()
# Out:
#    CGPA  GRE Score  TOEFL Score  University Rating  SOP  LOR  Research  \
# 0  9.65        337          118                  4  4.5  4.5         1
# 1  8.00        316          104                  3  3.0  3.5         1
# 2  8.67        322          110                  3  3.5  2.5         1
# 3  8.21        314          103                  2  2.0  3.0         0
# 4  9.34        330          115                  5  4.5  3.0         1
#
#    Chance of Admit
# 0             0.92
# 1             0.72
# 2             0.80
# 3             0.65
# 4             0.90

# %% [markdown]
# # Challenge 2 - Advanced Functions
#
# In this part of the lab, we would like to test complex conditions on the entire dataset at once. Let's start by finding the number of rows where the CGPA is higher than 9 and the student has conducted research.

# %%
# Your code here:
admissions[(admissions['CGPA'] > 9) * admissions['Research'] == 1]
# Out:
#      CGPA  GRE Score  TOEFL Score  University Rating  SOP  LOR  Research  \
# 0    9.65        337          118                  4  4.5  4.5         1
# 4    9.34        330          115                  5  4.5  3.0         1
# 10   9.10        328          112                  4  4.0  4.5         1
# 19   9.50        328          116                  5  5.0  5.0         1
# 20   9.70        334          119                  5  5.0  4.5         1
# ..    ...        ...          ...                ...  ...  ...       ...
# 379  9.23        329          111                  4  4.5  4.0         1
# 380  9.04        324          110                  3  3.5  3.5         1
# 381  9.11        325          107                  3  3.0  3.5         1
# 382  9.45        330          116                  4  5.0  4.5         1
# 384  9.66        333          117                  4  5.0  4.0         1
#
#      Chance of Admit
# 0               0.92
# 4               0.90
# 10              0.78
# 19              0.94
# 20              0.95
# ..               ...
# 379             0.89
# 380             0.82
# 381             0.84
# 382             0.91
# 384             0.95
#
# [101 rows x 8 columns]

# %% [markdown]
# Now return all the rows where the CGPA is greater than 9 and the SOP score is less than 3.5. Find the mean chance of admit for these applicants.

# %%
# Your code here:
(admissions[(admissions['CGPA'] > 9) * admissions['SOP'] < 3.5])['Chance of Admit'].mean()
# Out:
# 0.6631428571428568

# %% [markdown]
# We would like to create a deciding factor column for each student. We standardize several columns and then pick the most important factor from a lookup table. If the standardized value is above 0.8, the student will be accepted.
#
# We will start by creating a standardized column for `CGPA`, `GRE Score` and `LOR`. We will name these columns `CGPA_std`, `GRE_std`, and `LOR_std` respecively.
#
# Recall that standardizing a column is done by subtracting the mean of the column from all observations in the column and then dividing each observation in the column by the column's standard deviation.
#
# In the cell below, write a standardization function (a function that takes a column as input and returns a standardized column as output). Make sure to use the `numpy` versions of mean and standard deviation.

# %%
def standardize(col):
    # This function takes a column from a dataframe and returns a standardized column by subtracting the column's mean
    # and dividing by the column's standard deviation.
    
    # Your code here:
    return (col - col.mean()) / col.std()

# %% [markdown]
# Now create the standardized columns `CGPA_std`, `GRE_std`, and `LOR_std` and add them to the `admissions` dataframe.

# %%
# Your code here:
admissions['CGPA_std'] = standardize(admissions['CGPA'])
admissions['GRE_std'] = standardize(admissions['GRE Score'])
admissions['LOR_std'] = standardize(admissions['LOR'])

admissions.head()
# Out:
#    CGPA  GRE Score  TOEFL Score  University Rating  SOP  LOR  Research  \
# 0  9.65        337          118                  4  4.5  4.5         1
# 1  8.00        316          104                  3  3.0  3.5         1
# 2  8.67        322          110                  3  3.5  2.5         1
# 3  8.21        314          103                  2  2.0  3.0         0
# 4  9.34        330          115                  5  4.5  3.0         1
#
#    Chance of Admit  CGPA_std   GRE_std   LOR_std
# 0             0.92  1.747900  1.753381  1.191647
# 1             0.72 -0.991211 -0.063367  0.076740
# 2             0.80  0.121034  0.455704 -1.038166
# 3             0.65 -0.642597 -0.236391 -0.480713
# 4             0.90  1.233279  1.147798 -0.480713

# %% [markdown]
# We will generate the decision choice at random using the code below. Please run the cell.

# %%
# Run this code:

from random import choices
std_columns = ['CGPA_std', 'GRE_std', 'LOR_std']

decision_choice = choices(std_columns, k=admissions.shape[0])

# %% [markdown]
# Now create the deciding column using the `lookup` function. The lookup column is `decision_choice` found above. Call the column resulting from the lookup function `deciding_column` and add it to the `admissions` dataframe.

# %%
# Your code here:
admissions['deciding_column'] = admissions.lookup(admissions.index, decision_choice)
admissions.head()
# Out:
#    CGPA  GRE Score  TOEFL Score  University Rating  SOP  LOR  Research  \
# 0  9.65        337          118                  4  4.5  4.5         1
# 1  8.00        316          104                  3  3.0  3.5         1
# 2  8.67        322          110                  3  3.5  2.5         1
# 3  8.21        314          103                  2  2.0  3.0         0
# 4  9.34        330          115                  5  4.5  3.0         1
#
#    Chance of Admit  CGPA_std   GRE_std   LOR_std  deciding_column
# 0             0.92  1.747900  1.753381  1.191647         1.753381
# 1             0.72 -0.991211 -0.063367  0.076740        -0.063367
# 2             0.80  0.121034  0.455704 -1.038166         0.455704
# 3             0.65 -0.642597 -0.236391 -0.480713        -0.642597
# 4             0.90  1.233279  1.147798 -0.480713        -0.480713

# %% [markdown]
# Create a column called `decision` in the `admissions` dataframe. Assign 1 to this column if the value of `deciding_column` is greater than 0.8 and 0 otherwise.

# %%
# Your code here:
admissions['decision'] = np.where(admissions['deciding_column'] > 0.8, 1, 0)
admissions.head()
# Out:
#    CGPA  GRE Score  TOEFL Score  University Rating  SOP  LOR  Research  \
# 0  9.65        337          118                  4  4.5  4.5         1
# 1  8.00        316          104                  3  3.0  3.5         1
# 2  8.67        322          110                  3  3.5  2.5         1
# 3  8.21        314          103                  2  2.0  3.0         0
# 4  9.34        330          115                  5  4.5  3.0         1
#
#    Chance of Admit  CGPA_std   GRE_std   LOR_std  deciding_column  decision
# 0             0.92  1.747900  1.753381  1.191647         1.753381         1
# 1             0.72 -0.991211 -0.063367  0.076740        -0.063367         0
# 2             0.80  0.121034  0.455704 -1.038166         0.455704         0
# 3             0.65 -0.642597 -0.236391 -0.480713        -0.642597         0
# 4             0.90  1.233279  1.147798 -0.480713        -0.480713         0

# %% [markdown]
# How many applicants will be accepted to the program using the decision column? Compute the result below.

# %%
# Your code here:
admissions.query('decision == 1').count()
# Out:
# CGPA                 84
# GRE Score            84
# TOEFL Score          84
# University Rating    84
# SOP                  84
# LOR                  84
# Research             84
# Chance of Admit      84
# CGPA_std             84
# GRE_std              84
# LOR_std              84
# deciding_column      84
# decision             84
# dtype: int64

# %% [markdown]
# # Challenge 3 - Method Chaining
#
# To increase our coding efficiency, let's make a number of changes to our dataframe in one line of code.
#
# In the cell below, remove all non character symbols from the column names, replace all spaces in column names to underscores, and change all upper case characters to lower case. Assign these new column values to `admissions.columns`.

# %%
# Your code here:
admissions.columns = admissions.columns.str.replace('.','').str.lower().str.replace(' ','_')
admissions.head()
# Out:
#    cgpa  gre_score  toefl_score  university_rating  sop  lor  research  \
# 0  9.65        337          118                  4  4.5  4.5         1
# 1  8.00        316          104                  3  3.0  3.5         1
# 2  8.67        322          110                  3  3.5  2.5         1
# 3  8.21        314          103                  2  2.0  3.0         0
# 4  9.34        330          115                  5  4.5  3.0         1
#
#    chance_of_admit  cgpa_std   gre_std   lor_std  deciding_column  decision
# 0             0.92  1.747900  1.753381  1.191647         1.753381         1
# 1             0.72 -0.991211 -0.063367  0.076740        -0.063367         0
# 2             0.80  0.121034  0.455704 -1.038166         0.455704         0
# 3             0.65 -0.642597 -0.236391 -0.480713        -0.642597         0
# 4             0.90  1.233279  1.147798 -0.480713        -0.480713         0

# %% [markdown]
# In the cell below, give all student with a university rating of 4 or higher a 10 point boost on their GRE score and split the column into 4 bins using the `cut` function. Assign this new score to the variable `adjusted_gre`.

# %%
# Your code here:

adjusted_gre = pd.cut(admissions['university_rating'],[1,2,3,4,5])

admissions['adjusted_gre'] = np.where(admissions['university_rating'] >= 4, admissions['gre_score'] + 10,
                                                                 admissions['gre_score'])

# %%
admissions.head(20)
# Out:
#     cgpa  gre_score  toefl_score  university_rating  sop  lor  research  \
# 0   9.65        337          118                  4  4.5  4.5         1
# 1   8.00        316          104                  3  3.0  3.5         1
# 2   8.67        322          110                  3  3.5  2.5         1
# 3   8.21        314          103                  2  2.0  3.0         0
# 4   9.34        330          115                  5  4.5  3.0         1
# 5   8.20        321          109                  3  3.0  4.0         1
# 6   7.90        308          101                  2  3.0  4.0         0
# 7   8.00        302          102                  1  2.0  1.5         0
# 8   8.60        323          108                  3  3.5  3.0         0
# 9   9.00        327          111                  4  4.0  4.5         1
# 10  9.10        328          112                  4  4.0  4.5         1
# 11  8.00        307          109                  3  4.0  3.0         1
# 12  8.20        311          104                  3  3.5  2.0         1
# 13  8.30        314          105                  3  3.5  2.5         0
# 14  8.70        317          107                  3  4.0  3.0         0
# 15  8.00        319          106                  3  4.0  3.0         1
# 16  8.80        318          110                  3  4.0  3.0         0
# 17  8.50        303          102                  3  3.5  3.0         0
# 18  8.40        325          114                  4  3.0  2.0         0
# 19  9.50        328          116                  5  5.0  5.0         1
#
#     chance_of_admit  cgpa_std   gre_std   lor_std  deciding_column  decision  \
# 0              0.92  1.747900  1.753381  1.191647         1.753381         1
# 1              0.72 -0.991211 -0.063367  0.076740        -0.063367         0
# 2              0.80  0.121034  0.455704 -1.038166         0.455704         0
# 3              0.65 -0.642597 -0.236391 -0.480713        -0.642597         0
# 4              0.90  1.233279  1.147798 -0.480713        -0.480713         0
# 5              0.75 -0.659198  0.369192  0.634193         0.634193         0
# 6              0.68 -1.157218 -0.755462  0.634193        -0.755462         0
# 7              0.50 -0.991211 -1.274533 -2.153072        -2.153072         0
# 8              0.45  0.004829  0.542216 -0.480713         0.542216         0
# 9              0.84  0.668856  0.888263  1.191647         0.668856         0
# 10             0.78  0.834863  0.974775  1.191647         0.834863         1
# 11             0.62 -0.991211 -0.841973 -0.480713        -0.991211         0
# 12             0.61 -0.659198 -0.495926 -1.595619        -0.659198         0
# 13             0.54 -0.493191 -0.236391 -1.038166        -1.038166         0
# 14             0.66  0.170836  0.023145 -0.480713        -0.480713         0
# 15             0.65 -0.991211  0.196168 -0.480713        -0.991211         0
# 16             0.63  0.336843  0.109657 -0.480713         0.336843         0
# 17             0.62 -0.161177 -1.188021 -0.480713        -1.188021         0
# 18             0.70 -0.327184  0.715239 -1.595619         0.715239         0
# 19             0.94  1.498890  0.974775  1.749100         1.498890         1
#
#     adjusted_gre
# 0            347
# 1            316
# 2            322
# 3            314
# 4            340
# 5            321
# 6            308
# 7            302
# 8            323
# 9            337
# 10           338
# 11           307
# 12           311
# 13           314
# 14           317
# 15           319
# 16           318
# 17           303
# 18           335
# 19           338
