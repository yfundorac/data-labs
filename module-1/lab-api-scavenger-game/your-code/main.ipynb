# %% [markdown]
# # Challenge 1: Fork Languages
#
# You will find out how many programming languages are used among all the forks created from the main lab repo of your bootcamp. Assuming the main lab repo is ironhack-datalabs/madrid-oct-2018, you will:
#
# Obtain the full list of forks created from the main lab repo via Github API.
#
# Loop the JSON response to find out the language attribute of each fork. Use an array to store the language attributes of each fork.
#
# Hint: Each language should appear only once in your array.
# Print the language array. It should be something like:
#
# ["Python", "Jupyter Notebook", "HTML"]

# %%
import requests
url = "https://api.github.com/repos/ironhack-datalabs/madrid-oct-2018/forks"
response = requests.get(url)
results = response.json()

# %%
language = []
for l in results:
    if l['language'] not in language:
        language.append(l['language'])
        
language
# Out:
# ['Jupyter Notebook', 'HTML', 'Python']

# %% [markdown]
# # Challenge 2: Count Commits
# Count how many commits were made in the past week.
#
# Obtain all the commits made in the past week via API, which is a JSON array that contains multiple commit objects.
#
# Count how many commit objects are contained in the array.

# %%
url = "https://api.github.com/repos/ironhack-datalabs/madrid-oct-2018/commits?since=2019-09-22T00:00:00&until=2019-09-28T23:59:00"
commits = requests.get(url)
results = commits.json()
count_commits = len(results)
count_commits
# Out:
# 0

# %% [markdown]
# # Challenge 3: Hidden Cold Joke
# Using Python, call Github API to find out the cold joke contained in the 24 secret files in the following repo:
#
# https://github.com/ironhack-datalabs/scavenger
#
# The filenames of the secret files contain .scavengerhunt and they are scattered in different directories of this repo. The secret files are named from .0001.scavengerhunt to .0024.scavengerhunt. They are scattered randomly throughout this repo. You need to search for these files by calling the Github API, not searching the local files on your computer.

# %%
import base64 as base64

def inspect_dir(url, list_result):
    response = requests.get(url)
    contents = response.json()
    for obj in contents:
        if obj['type'] == "file" and ".scavengerhunt" in obj['name']:
            file_response = requests.get(obj['url'])
            file_content = file_response.json()
            cont = base64.b64decode(file_content['content']).decode('utf-8')
            list_result[obj['name']] = cont
        elif obj['type'] == "dir":
            inspect_dir(obj['url'], list_result)

# %%
list_res = {}
inspect_dir("https://api.github.com/repos/ironhack-datalabs/scavenger/contents", list_res)
string = ''
for i in sorted (list_res): 
    string = string + ' ' + list_res[i]
print (string)
# Out:
#  In
#  data
#  science,
#  80
#  percent
#  of
#  time
#  spent
#  is
#  preparing
#  data,
#  20
#  percent
#  of
#  time
#  is
#  spent
#  complaining
#  about
#  the
#  need
#  to
#  prepare
#  data.

# %% [markdown]
# # Additional Challenge for the Nerds

# %%
import os
os.mknod(test.txt)
url = 'https://api.github.com/repos/yfundorac/test-repo/contents/'
json = {
  "message": "Added a test.txt file to my test-repo",
  "committer": {
    "name": "Yailin Fundora",
    "email": "yfundorac@gmail.com"
  },
  "content": "Q29udGVudCBvZiBteSB0ZXh0LnR4dCBmaWxl"
}
response = requests.put(url, data =  json)
response
# Out:
# <Response [404]>

# %%
requests.get('https://api.github.com/repos/yfundorac/test-repo').json()
# Out:
# {'id': 212217106,
#  'node_id': 'MDEwOlJlcG9zaXRvcnkyMTIyMTcxMDY=',
#  'name': 'test-repo',
#  'full_name': 'yfundorac/test-repo',
#  'private': False,
#  'owner': {'login': 'yfundorac',
#   'id': 52225555,
#   'node_id': 'MDQ6VXNlcjUyMjI1NTU1',
#   'avatar_url': 'https://avatars2.githubusercontent.com/u/52225555?v=4',
#   'gravatar_id': '',
#   'url': 'https://api.github.com/users/yfundorac',
#   'html_url': 'https://github.com/yfundorac',
#   'followers_url': 'https://api.github.com/users/yfundorac/followers',
#   'following_url': 'https://api.github.com/users/yfundorac/following{/other_user}',
#   'gists_url': 'https://api.github.com/users/yfundorac/gists{/gist_id}',
#   'starred_url': 'https://api.github.com/users/yfundorac/starred{/owner}{/repo}',
#   'subscriptions_url': 'https://api.github.com/users/yfundorac/subscriptions',
#   'organizations_url': 'https://api.github.com/users/yfundorac/orgs',
#   'repos_url': 'https://api.github.com/users/yfundorac/repos',
# ...

# %%
requests.get('https://api.github.com/repos/ironhack-datalabs/scavenger/contents').json()
# Out:
# [{'name': '.gitignore',
#   'path': '.gitignore',
#   'sha': 'e43b0f988953ae3a84b00331d0ccf5f7d51cb3cf',
#   'size': 10,
#   'url': 'https://api.github.com/repos/ironhack-datalabs/scavenger/contents/.gitignore?ref=master',
#   'html_url': 'https://github.com/ironhack-datalabs/scavenger/blob/master/.gitignore',
#   'git_url': 'https://api.github.com/repos/ironhack-datalabs/scavenger/git/blobs/e43b0f988953ae3a84b00331d0ccf5f7d51cb3cf',
#   'download_url': 'https://raw.githubusercontent.com/ironhack-datalabs/scavenger/master/.gitignore',
#   'type': 'file',
#   '_links': {'self': 'https://api.github.com/repos/ironhack-datalabs/scavenger/contents/.gitignore?ref=master',
#    'git': 'https://api.github.com/repos/ironhack-datalabs/scavenger/git/blobs/e43b0f988953ae3a84b00331d0ccf5f7d51cb3cf',
#    'html': 'https://github.com/ironhack-datalabs/scavenger/blob/master/.gitignore'}},
#  {'name': '15024',
#   'path': '15024',
#   'sha': '2945e51c87ad5da893c954afcf092f06343bbb7d',
#   'size': 0,
# ...
